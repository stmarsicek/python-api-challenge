# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0    viedma -40.8135  -62.9967     46.35        81          62
# 1        1      weno   7.4515  151.8468     82.42        75          89
# 2        2    kodiak  57.7900 -152.4072     62.11        72           0
# 3        3  luchenza -16.0069   35.3095     54.14        96          17
# 4        4  portland  45.5234 -122.6762     79.56        45           0
#
#    Wind Speed Country        Date
# 0       13.53      AR  1690336778
# 1        5.57      FM  1690336779
# 2       11.50      US  1690336779
# 3        3.33      MW  1690336779
# 4        9.22      US  1690336651

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_1 = city_data_df.hvplot.points(
    'Lng',
    'Lat',
    size = Humidity,
    geo = True,
    tiles = "OSM",
    color = 'City',
    frame_width= 700,
    frame_height= 500,
)

# Display the map
# YOUR CODE HERE
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,_size)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Criteria max temp no greater than 90 no less than 70, Humidity less than 85 and cloudiness = 0
# YOUR CODE HERE
df = city_data_df.loc[(city_data_df['Max Temp']<90) & (city_data_df['Max Temp']>=70) &
(city_data_df['Humidity']<85) & (city_data_df['Cloudiness'] == 0)]
# Drop any rows with null values
# YOUR CODE HERE
df = df.dropna()
# Display sample data
# YOUR CODE HERE
df
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 4          4                     portland  45.5234 -122.6762     79.56
# 17        17        conceicao do araguaia  -8.2578  -49.2647     72.63
# 40        40                 san patricio  28.0170  -97.5169     87.19
# 42        42                        nalut  30.3333   10.8500     88.52
# 56        56  cuatro cienegas de carranza  26.9833 -102.0833     89.56
# 58        58                         kone -21.0595  164.8658     75.60
# 59        59                     hamilton  39.1834  -84.5333     79.65
# 108      108                          ino  33.5500  133.4333     85.53
# 123      123                   carbondale  37.7273  -89.2168     83.05
# 148      148                     alvorada -12.4800  -49.1247     76.10
# 149      149                       avarua -21.2078 -159.7750     75.25
# 185      185                      tortoli  39.9256    9.6572     75.02
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
# YOUR CODE HERE
hotel_df = df[['City', 'Country','Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# YOUR CODE HERE
hotel_df['Hotel Name'] = ""
# Display sample data
# YOUR CODE HERE
hotel_df
# Out:
#                             City Country      Lat       Lng  Humidity  \
# 4                       portland      US  45.5234 -122.6762        45
# 17         conceicao do araguaia      BR  -8.2578  -49.2647        48
# 40                  san patricio      US  28.0170  -97.5169        67
# 42                         nalut      LY  30.3333   10.8500        13
# 56   cuatro cienegas de carranza      MX  26.9833 -102.0833        29
# 58                          kone      NC -21.0595  164.8658        41
# 59                      hamilton      US  39.1834  -84.5333        72
# 108                          ino      JP  33.5500  133.4333        56
# 123                   carbondale      US  37.7273  -89.2168        77
# 148                     alvorada      BR -12.4800  -49.1247        37
# 149                       avarua      CK -21.2078 -159.7750        60
# 185                      tortoli      IT  39.9256    9.6572        46
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
cats= ' accommodation.hotel'
lon = 28.538336
lat = -81.379234
rad = 1000000
filtr =f'circle:{lat},{lon},{rad}'
limit = 10
params = {
    
    'categories': cats,
    'filter': filtr,
    'apiKey': geoapify_key

}

base_url = 'https://api.geoapify.com/v2/places'


resp = requests.get(base_url, params=params).json()

resp
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Holiday Inn Resort Orlando Suites Waterpark',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Florida',
#     'county': 'Orange County',
#     'city': 'Orlando',
#     'postcode': '32821',
#     'street': 'Continental Gateway Drive',
#     'housenumber': '14500',
#     'lon': -81.51147145532717,
#     'lat': 28.35676485,
#     'state_code': 'FL',
#     'formatted': 'Holiday Inn Resort Orlando Suites Waterpark, 14500 Continental Gateway Drive, Orlando, FL 32821, United States of America',
#     'address_line1': 'Holiday Inn Resort Orlando Suites Waterpark',
#     'address_line2': '14500 Continental Gateway Drive, Orlando, FL 32821, United States of America',
#     'categories': ['accommodation',
#      'accommodation.hotel',
#      'building',
#      'building.accommodation'],
#     'details': ['details', 'details.contact', 'details.wiki_and_media'],
# ...

# %%
# Set parameters to search for a hotel
cats= 'accommodation.hotel'
filtr =f'circle:{lat},{lon},{rad}'
rad = 10000
limit = 10
params = {
    
    'categories': cats,
    'apiKey': geoapify_key,
    'filter': filtr 

}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row['Lng']
    lat = row['Lat']
    rad = 10000
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{rad}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params).json()
    
    # Convert the API response to JSON format
#     name_address = # YOUR CODE HERE did this above in one step
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# portland - nearest hotel: the Hoxton
# conceicao do araguaia - nearest hotel: No hotel found
# san patricio - nearest hotel: No hotel found
# nalut - nearest hotel: No hotel found
# cuatro cienegas de carranza - nearest hotel: No hotel found
# kone - nearest hotel: Pacifik Appartels
# hamilton - nearest hotel: North Vista Manor
# ino - nearest hotel: オリエンタルプライベートスペース ラジャイスタナ
# carbondale - nearest hotel: Quality Inn Carbondale
# alvorada - nearest hotel: No hotel found
# avarua - nearest hotel: Paradise Inn
# tortoli - nearest hotel: La Corte
# alexandria - nearest hotel: Smoha Zahran Haus (7th floor)
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# pacific grove - nearest hotel: Pacific Grove Inn
# ak-suu - nearest hotel: BellavistaHotel
# misratah - nearest hotel: الفندق السياحى
# orchard homes - nearest hotel: Broadway Inn
# birjand - nearest hotel: مهمانسرای جهانگردی بیرجند
# awjilah - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE
map_plot_2 = hotel_df.hvplot.points(
    'Lng',
    'Lat',
    size = Humidity,
    geo = True,
    tiles = "OSM",
    color = 'City',
    frame_width= 700,
    frame_height= 500,
    hover_cols=['Hotel Name','Country']
)
# Display the map
# YOUR CODE HERE
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,_size,Hotel Name,Country)
